# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load data
y_train = pd.read_csv('data/train_labels.csv')
X_train = pd.read_csv('data/train_values.csv')
X_test = pd.read_csv('data/test_values.csv')

# %%
sns.heatmap(X_test.select_dtypes(include='number').corr())
# Out:
# <Axes: >

# %%
X_test.select_dtypes(include='number').corr()
# Out:
#                                         building_id  geo_level_1_id  \
# building_id                                1.000000       -0.002946
# geo_level_1_id                            -0.002946        1.000000
# geo_level_2_id                            -0.003090       -0.057252
# geo_level_3_id                             0.004068       -0.000894
# count_floors_pre_eq                        0.005588       -0.079154
# age                                        0.003798        0.002471
# area_percentage                            0.000946        0.073723
# height_percentage                          0.007119       -0.060458
# has_superstructure_adobe_mud               0.000114       -0.014669
# has_superstructure_mud_mortar_stone       -0.003159       -0.153907
# has_superstructure_stone_flag             -0.001232        0.006269
# has_superstructure_cement_mortar_stone    -0.000994        0.029591
# has_superstructure_mud_mortar_brick        0.007147       -0.027979
# ...
